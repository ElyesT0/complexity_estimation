# %%
from modules import *
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
raw_data_path="/Users/elyestabbane/Documents/UNICOG/2-Experiments/complexity_estimation/2-Data/online_exp_data/raw"
all_data_path=os.path.join(processed_data_path,'aggregated_data.json')
df=pd.read_json(all_data_path)

# %% [markdown]
# <b>Sequences probes sanity checks:</b> <br>
# training-1 <br>
# training-2 <br>
# training-3 <br>
# training-4 <br>
# probe-easy <br>
# probe-hard-1 <br>
# probe-hard-2 <br>
# probe-hard-3 <br>
# probe-hard-4 <br>
# probe-hard-5

# %%
sanity_check_plot_colors=['grey' for name in sanity_checks_sequence_names]
plot_mean_complexity_estimate(df,sanity_checks_sequence_names,file_name='sanity_checks',path=sanity_checks_plots,print_values=True,seq_expression=True,unfill_controls=False,colors_figure=sanity_check_plot_colors,save=True)
# Out:
# [training-1] mean Complexity Estimate: 0.89
# [training-1] SEM: 0.11
#
# [training-2] mean Complexity Estimate: 6.28
# [training-2] SEM: 0.46
#
# [training-3] mean Complexity Estimate: 1.72
# [training-3] SEM: 0.3
#
# [training-4] mean Complexity Estimate: 5.39
# [training-4] SEM: 0.58
#
# [probe-easy] mean Complexity Estimate: 0.43
# [probe-easy] SEM: 0.2
#
# [probe-hard-1] mean Complexity Estimate: 3.5
# [probe-hard-1] SEM: 0.81
#
# [probe-hard-2] mean Complexity Estimate: 3.83
# [probe-hard-2] SEM: 0.67
#
# [probe-hard-3] mean Complexity Estimate: 3.56
# [probe-hard-3] SEM: 0.72
#
# [probe-hard-4] mean Complexity Estimate: 3.78
# [probe-hard-4] SEM: 0.75
#
# [probe-hard-5] mean Complexity Estimate: 3.33
# [probe-hard-5] SEM: 0.78

# %%
sanity_check_plot_colors=['grey' for name in test_sequences_tempTags]
plot_mean_complexity_estimate(df,test_sequences_tempTags,file_name='test_sequences',path=sanity_checks_plots,print_values=True,seq_expression=True,unfill_controls=False,colors_figure=sanity_check_plot_colors,save=True)
# Out:
# [Rep2] mean Complexity Estimate: 0.89
# [Rep2] SEM: 0.28
#
# [CRep2] mean Complexity Estimate: 2.22
# [CRep2] SEM: 0.44
#
# [Rep3] mean Complexity Estimate: 1.22
# [Rep3] SEM: 0.34
#
# [CRep3] mean Complexity Estimate: 2.69
# [CRep3] SEM: 0.51
#
# [Rep4] mean Complexity Estimate: 1.69
# [Rep4] SEM: 0.42
#
# [CRep4] mean Complexity Estimate: 3.17
# [CRep4] SEM: 0.61
#
# [Rep-Nested] mean Complexity Estimate: 1.24
# [Rep-Nested] SEM: 0.39
#
# [Nested-Global-Rep] mean Complexity Estimate: 2.0
# [Nested-Global-Rep] SEM: 0.48
#
# [Nested-Local-Rep] mean Complexity Estimate: 1.89
# [Nested-Local-Rep] SEM: 0.44
#
# [Play] mean Complexity Estimate: 1.98
# [Play] SEM: 0.5
#
# [CPlay] mean Complexity Estimate: 2.28
# [CPlay] SEM: 0.56
#
# [Play4] mean Complexity Estimate: 2.52
# [Play4] SEM: 0.64
#
# [CPlay4] mean Complexity Estimate: 3.07
# [CPlay4] SEM: 0.63
#
# [Sub-1] mean Complexity Estimate: 2.5
# [Sub-1] SEM: 0.63
#
# [CSub-1] mean Complexity Estimate: 2.83
# [CSub-1] SEM: 0.7
#
# [Sub-2] mean Complexity Estimate: 3.08
# [Sub-2] SEM: 0.64
#
# [CSub-2] mean Complexity Estimate: 3.7
# [CSub-2] SEM: 0.67
#
# [Mirror-Rep] mean Complexity Estimate: 2.61
# [Mirror-Rep] SEM: 0.57
#
# [CMirror-Rep] mean Complexity Estimate: 2.87
# [CMirror-Rep] SEM: 0.59
#
# [Mirror-NoRep] mean Complexity Estimate: 2.31
# [Mirror-NoRep] SEM: 0.59
#
# [CMirror-NoRep] mean Complexity Estimate: 3.02
# [CMirror-NoRep] SEM: 0.6
#
# [Index] mean Complexity Estimate: 1.54
# [Index] SEM: 0.47
#
# [CIndex] mean Complexity Estimate: 1.57
# [CIndex] SEM: 0.43
#
# [Suppression] mean Complexity Estimate: 2.89
# [Suppression] SEM: 0.64
#
# [Insertion] mean Complexity Estimate: 2.65
# [Insertion] SEM: 0.6

# %%
duration_stats(df)
# Out:
# There are 12 unique datasets of at least 80 trials
# Mean duration : 14.39
# Median duration : 13.98
# Max duration : 20.784983333333333
# Min duration : 12.031633333333334
