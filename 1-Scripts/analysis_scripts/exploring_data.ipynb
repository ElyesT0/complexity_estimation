# %%
from modules import *
# %load_ext autoreload
# %autoreload 2

# %%
df=pd.read_json(merged_processed_path)

# %%
# Check -- Excluded participants are not in the data anymore.
#
#unique_ids=[name for name in df["participant_ID"].unique()]
#np.isin(excluded_participants,unique_ids)

# %%
# Next step: think about how to plot the comparison between different geometrical conditions
# Maybe two plots:
# -- 1. Estimated complexity per geometrical condition
# -- 2. Estimated complexity (x-axis) per temporal condition (y-axis) with one point
#       per geometrical condition (roughly 3 points per line).

# %%
plot_mean_estimated_complexity(df,path="",print_values=True,seq_expression=True,sequences=test_sequences_tempTags,save=False,unfill_controls=True, colors_figure=distinct_colors_all)
# Out:
# [Rep2] mean estimated complexity: 1.67
# [Rep2] SEM: 0.11
#
# [CRep2] mean estimated complexity: 2.93
# [CRep2] SEM: 0.11
#
# [Rep3] mean estimated complexity: 2.18
# [Rep3] SEM: 0.12
#
# [CRep3] mean estimated complexity: 4.03
# [CRep3] SEM: 0.1
#
# [Rep4] mean estimated complexity: 3.17
# [Rep4] SEM: 0.12
#
# [CRep4] mean estimated complexity: 4.83
# [CRep4] SEM: 0.11
#
# [Rep-Nested] mean estimated complexity: 2.35
# [Rep-Nested] SEM: 0.12
#
# [Nested-Global-Rep] mean estimated complexity: 3.49
# [Nested-Global-Rep] SEM: 0.12
#
# [Nested-Local-Rep] mean estimated complexity: 2.99
# [Nested-Local-Rep] SEM: 0.11
#
# [Play] mean estimated complexity: 3.38
# [Play] SEM: 0.11
#
# [CPlay] mean estimated complexity: 3.72
# [CPlay] SEM: 0.11
#
# [Play4] mean estimated complexity: 4.3
# [Play4] SEM: 0.11
#
# [CPlay4] mean estimated complexity: 4.94
# [CPlay4] SEM: 0.11
#
# [Sub-1] mean estimated complexity: 4.1
# [Sub-1] SEM: 0.13
#
# [CSub-1] mean estimated complexity: 4.67
# [CSub-1] SEM: 0.15
#
# [Sub-2] mean estimated complexity: 4.69
# [Sub-2] SEM: 0.11
#
# [CSub-2] mean estimated complexity: 5.53
# [CSub-2] SEM: 0.1
#
# [Mirror-Rep] mean estimated complexity: 3.85
# [Mirror-Rep] SEM: 0.11
#
# [CMirror-Rep] mean estimated complexity: 4.53
# [CMirror-Rep] SEM: 0.1
#
# [Mirror-NoRep] mean estimated complexity: 4.2
# [Mirror-NoRep] SEM: 0.1
#
# [CMirror-NoRep] mean estimated complexity: 4.57
# [CMirror-NoRep] SEM: 0.1
#
# [Index] mean estimated complexity: 2.66
# [Index] SEM: 0.11
#
# [CIndex] mean estimated complexity: 2.71
# [CIndex] SEM: 0.1
#
# [Suppression] mean estimated complexity: 4.59
# [Suppression] SEM: 0.11
#
# [Insertion] mean estimated complexity: 4.01
# [Insertion] SEM: 0.09
